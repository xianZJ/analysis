Y5HD0TA3qn0KkUgfqn0KkUgnqn0KbugwxmLK95H00XMfqn0KVmdqhThqV5HKxn7tsg100uA78IyF-gLK_my4GuZnqn7tsg1Kxn0Ksmgwxuhk9u1Ys0AwWpyfqn0K-IA-b5iYk0A71TAPW5H00IgKGUhPW5H00Tydh5H00uhPdIjYs0A-1mvsqn0KlTAkdT1Ys0A7buhk9u1Y30Akhm1Ys0AwWmvfq0AqW5HD0mMfqn0KEIjYk0AqzTZfqnBnsc1Dsc1cWnWRYrj63Pj6WnW0snanznj0sQW0snj0snankc1cWn0KWThnqPjfsnWn%26word%3Dboss%26ck%3D1671.7.120.412.182.296.221.611%26shh%3Dwww.baidu.com%26sht%3D88093251_30_hao_pg%26us%3D1.0.1.0.1.313.0%26bc%3D110101&g=%2Fwww.zhipin.com%2Fuser%2Fsem7.html%3Fsid%3Dsem%26qudao%3Dbdpc_baidu-%25E5%258D%258E%25E5%2593%2581%25E5%258D%259A%25E7%259D%25BF02A18KA0679%26plan%3DNew-%25E5%2593%2581%25E7%2589%258C%25E8%25AF%258D-05%26unit%3D%25E5%2593%2581%25E7%2589%258C-%25E6%25A0%25B8%25E5%25BF%2583%26keyword%3Dboss%25E7%259B%25B4%25E8%2581%2598%25E4%25BC%2581%25E4%25B8%259A%25E7%2599%25BB%25E5%25BD%2595%26bd_vid%3D8676326330776310018&friend_source=0&friend_source=0; Hm_lvt_194df3105ad7148dcf2b98a91b5e727a=1572228319,1572228332; t=2P7sdOeacqp4Vgs; wt=2P7sdOeacqp4Vgs; __a=59522724.1566978645.1566978645.1572228319.10.2.9.9; Hm_lpvt_194df3105ad7148dcf2b98a91b5e727a=1572240680; __zp_stoken__=e0a5JAT5moM9mymkgFH2tsIcsB9QbRY8sMEm4ZyrNZrW1CaNHNg9RA3IGlgPWE8u5vWqgO%2FaRC0ReaGPNWx4WhAUnw%3D%3D; __zp_sseed__=DDwFal1cFjNwuF59QE+fly+vJr1zjp3FEsKloWQyqig=; __zp_sname__=448e2e1c; __zp_sts__=1572240858252'
         }

response = requests.get(url,headers=page_headers)

bs = BeautifulSoup(response.text,'lxml')
print(bs)
print(bs.title)
print("【西安web前端开发招聘】")
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <title>è¯·ç¨å</title>
# <style>
#             html,
#             body {
#                 margin: 0;
#                 width: 100%;
#                 height: 100%;
#             }
#             @keyframes bossLoading {
#                 0% {
#                     transform: translate3d(0, 0, 0);
#                 }
#                 50% {
#                     transform: translate3d(0, -10px, 0);
#                 }
#             }
#             .data-tips {
#                 text-align: center;
#                 height: 100%;
#                 position: relative;
#                 background: #fff;
#                 top: 50%;
#                 margin-top: -37px;
#             }
#             .data-tips .boss-loading {
# ...

# %%
payload = {'business_scope': "电商",'legal_person': "刘强东",'name': "阿里巴巴",'official_website': "www.jd.com",'products': "jd",'source': 0}
requests.post('http://localhost:9527/api/company/add',data=payload)
# Out:
# <Response [200]>
